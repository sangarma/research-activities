# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import raw data
data = pd.read_csv("nutrition_data.csv")
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr                    Class  Data_Value  \
# 0       2020     2020           US        Physical Activity        30.6
# 1       2014     2014           GU  Obesity / Weight Status        29.3
# 2       2013     2013           US  Obesity / Weight Status        28.8
# 3       2013     2013           US  Obesity / Weight Status        32.7
# 4       2015     2015           US        Physical Activity        26.6
#
#    Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   Sample_Size  \
# 0            30.6                  29.4                    31.8      31255.0
# 1            29.3                  25.7                    33.3        842.0
# 2            28.8                  28.1                    29.5      62562.0
# 3            32.7                  31.9                    33.5      60069.0
# 4            26.6                  25.6                    27.6      30904.0
#
# ...

# %%
data.describe()
# Out:
#           YearStart       YearEnd    Data_Value  Data_Value_Alt  \
# count  88629.000000  88629.000000  79851.000000    79851.000000
# mean    2016.011362   2016.011362     31.236493       31.236493
# std        3.121080      3.121080     10.113829       10.113829
# min     2011.000000   2011.000000      0.900000        0.900000
# 25%     2013.000000   2013.000000     24.300000       24.300000
# 50%     2016.000000   2016.000000     31.200000       31.200000
# 75%     2019.000000   2019.000000     37.000000       37.000000
# max     2021.000000   2021.000000     77.600000       77.600000
#
#        Low_Confidence_Limit  High_Confidence_Limit     Sample_Size  \
# count          79851.000000            79851.000000   79851.000000
# mean              26.907732               36.135953    3656.809044
# std                9.907896               11.061591   18706.392637
# min                0.300000                3.000000      50.000000
# ...

# %%
# na values count
df = data.loc[data['LocationID'] == ]
df = df.loc[data['YearStart'] == 2011]
df.to_csv("df.csv", columns= data.columns)

# %%
drop_cols = ["LocationDesc","Datasource", "Topic","Data_Value_Unit","Data_Value_Footnote_Symbol","Data_Value_Footnote","Total", "DataValue"]
data.drop(["LocationDesc","Datasource", "Topic","Data_Value_Unit","Data_Value_Footnote_Symbol","Data_Value_Footnote","Total", "DataValueTypeID"], axis=1)
# Out:
#        YearStart  YearEnd LocationAbbr                    Class  \
# 0           2020     2020           US        Physical Activity
# 1           2014     2014           GU  Obesity / Weight Status
# 2           2013     2013           US  Obesity / Weight Status
# 3           2013     2013           US  Obesity / Weight Status
# 4           2015     2015           US        Physical Activity
# ...          ...      ...          ...                      ...
# 88624       2021     2021           ND    Fruits and Vegetables
# 88625       2021     2021           PR        Physical Activity
# 88626       2021     2021           WI        Physical Activity
# 88627       2021     2021           UT    Fruits and Vegetables
# 88628       2021     2021           US        Physical Activity
#
#                                                 Question Data_Value_Type  \
# 0      Percent of adults who engage in no leisure-tim...           Value
# ...

# %%
data.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  88629.000000  88629.000000              0.0  79851.000000
# mean    2016.011362   2016.011362              NaN     31.236493
# std        3.121080      3.121080              NaN     10.113829
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2013.000000   2013.000000              NaN     24.300000
# 50%     2016.000000   2016.000000              NaN     31.200000
# 75%     2019.000000   2019.000000              NaN     37.000000
# max     2021.000000   2021.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    79851.000000          79851.000000            79851.000000
# mean        31.236493             26.907732               36.135953
# std         10.113829              9.907896               11.061591
# min          0.900000              0.300000                3.000000
# ...

# %%
data.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'Class', 'Data_Value',
#        'Data_Value_Alt', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')
